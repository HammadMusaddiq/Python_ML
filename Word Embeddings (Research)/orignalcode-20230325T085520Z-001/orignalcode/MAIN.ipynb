# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install scipy>=1.6
# !pip install gensim==3.5.0
# !pip install PyQt5

# %%
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.python.keras import backend as K

# %%
# !python DebiasMulticlassWordEmbedding-master/Debiasing/debias.py DebiasMulticlassWordEmbedding-master/Debiasing/data/w2vs/reddit.US.txt.tok.clean.cleanedforw2v_2.w2v inter default inter -hard -v -k 2
# Out:
# Loading embeddings from DebiasMulticlassWordEmbedding-master/Debiasing/data/w2vs/reddit.US.txt.tok.clean.cleanedforw2v_2.w2v
# c:\Users\Hammad\Desktop\Python New Code\Word Embeddings (PhD Thesis)\orignalcode-20230325T085520Z-001\orignalcode\DebiasMulticlassWordEmbedding-master\Debiasing
# Evaluation Set: Intersection
# Loading vocabulary from data/vocab/inter_attributes_optm.json
# Pruning Word Vectors... Starting with 44895
# 	Ended with 44895
# Identifying bias subspace
# (2, 50)
# Neutralizing and Equalizing
# --Performing Evaluation
# --Biased Evaluation Results
# Biased MAC: 0.8879280446130645
# --HARD Debiased Evaluation Results
# HARD MAC: 0.9132254913773311
# --HARD Debiased Cosine difference t-test 6.785325254068757e-08
# C:\Users\Hammad\Documents\Python_Envs\bert_trans_env\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# !python DebiasMulticlassWordEmbedding-master/Downstream/ToxicityDetectionLSTM.py
# Out:
# (409328, 50)
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# 0it [00:00, ?it/s]
# 3069it [00:00, 29681.67it/s]
# 8270it [00:00, 41629.33it/s]
# 13577it [00:00, 45558.38it/s]
# 19341it [00:00, 49294.68it/s]
# 24505it [00:00, 49760.41it/s]
# 30081it [00:00, 51709.63it/s]
# 35580it [00:00, 51966.67it/s]
# 41316it [00:00, 53060.92it/s]
# 44895it [00:00, 49629.75it/s]
#
# 0it [00:00, ?it/s]
# 2085it [00:00, 19888.84it/s]
# 5397it [00:00, 26673.56it/s]
# 8719it [00:00, 29011.31it/s]
# 12340it [00:00, 31182.02it/s]
# 15459it [00:00, 30571.91it/s]
# 18793it [00:00, 31082.94it/s]
# 22157it [00:00, 31455.52it/s]
# 25725it [00:00, 32359.72it/s]
# 29215it [00:00, 32676.52it/s]
# 32484it [00:01, 31446.50it/s]
# 35825it [00:01, 31558.97it/s]
# 39338it [00:01, 32073.17it/s]
# 42830it [00:01, 32322.53it/s]
# 44895it [00:01, 31256.99it/s]
# ...

# %%
# !python  DebiasMulticlassWordEmbedding-master/Downstream/ToxicityDetectionEval.py
# Out:
# ^C

# %%
import tensorflow as tf

m=tf.keras.models.load_model("DebiasMulticlassWordEmbedding-master/Downstream/models/savedModels/saved_model.h5")

# %%
m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 220)]        0           []
#
#  embedding (Embedding)          (None, 220, 50)      20466400    ['input_1[0][0]']
#
#  spatial_dropout1d (SpatialDrop  (None, 220, 50)     0           ['embedding[0][0]']
#  out1D)
#
#  bidirectional (Bidirectional)  (None, 220, 256)     184320      ['spatial_dropout1d[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 220, 256)    395264      ['bidirectional[0][0]']
#  )
#
#  global_max_pooling1d (GlobalMa  (None, 256)         0           ['bidirectional_1[0][0]']
#  xPooling1D)
#
#  global_average_pooling1d (Glob  (None, 256)         0           ['bidirectional_1[0][0]']
#  alAveragePooling1D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_max_pooling1d[0][0]',
# ...

# %%
m.trainer.save_checkpoint('checkpoint.pl')

# %%
torch.save(m.state_dict(), "model")
torch.save(m.state_dict(), './save.pt')

# %%
m.save('m.onnx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7c3a1cd8f7f2> in <module>
# ----> 1 m.save('m.onnx')
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/layers/rnn/base_rnn.py in _use_input_spec_as_call_signature(self)
#     297     @property
#     298     def _use_input_spec_as_call_signature(self):
# --> 299         if self.unroll:
#     300             # When the RNN layer is unrolled, the time step shape cannot be
# ...
