# %%
import pandas as pd

# Read in the CSV files
df_data = pd.read_csv("API_19_DS2_en_csv_v2_5455435\API_19_DS2_en_csv_v2_5455435.csv", header=2)
print(df_data.shape)
# Out:
# (20216, 68)

# %%
df_data.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Urban population (% of total population)
# 1        Aruba          ABW                          Urban population
# 2        Aruba          ABW        Urban population growth (annual %)
# 3        Aruba          ABW                         Population, total
# 4        Aruba          ABW              Population growth (annual %)
#
#       Indicator Code       1960          1961          1962          1963  \
# 0  SP.URB.TOTL.IN.ZS     50.776     50.761000     50.746000     50.730000
# 1        SP.URB.TOTL  27728.000  28330.000000  28764.000000  29157.000000
# 2        SP.URB.GROW        NaN      2.147858      1.520329      1.357042
# 3        SP.POP.TOTL  54608.000  55811.000000  56682.000000  57475.000000
# 4        SP.POP.GROW        NaN      2.179059      1.548572      1.389337
#
#            1964          1965  ...           2014           2015  \
# ...

# %%
df = df_data.set_index("Country Name")
df.head()
# Out:
#              Country Code                            Indicator Name  \
# Country Name
# Aruba                 ABW  Urban population (% of total population)
# Aruba                 ABW                          Urban population
# Aruba                 ABW        Urban population growth (annual %)
# Aruba                 ABW                         Population, total
# Aruba                 ABW              Population growth (annual %)
#
#                  Indicator Code       1960          1961          1962  \
# Country Name
# Aruba         SP.URB.TOTL.IN.ZS     50.776     50.761000     50.746000
# Aruba               SP.URB.TOTL  27728.000  28330.000000  28764.000000
# Aruba               SP.URB.GROW        NaN      2.147858      1.520329
# Aruba               SP.POP.TOTL  54608.000  55811.000000  56682.000000
# Aruba               SP.POP.GROW        NaN      2.179059      1.548572
#
#                       1963          1964          1965          1966  ...  \
# ...

# %%
df = df.drop('Unnamed: 67', axis=1)
df.columns
# Out:
# Index(['Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df = df.fillna(df.mean())
df.head()
# Out:
# C:\Users\Hammad\AppData\Local\Temp\ipykernel_15116\3457963863.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.mean())
#              Country Code                            Indicator Name  \
# Country Name
# Aruba                 ABW  Urban population (% of total population)
# Aruba                 ABW                          Urban population
# Aruba                 ABW        Urban population growth (annual %)
# Aruba                 ABW                         Population, total
# Aruba                 ABW              Population growth (annual %)
#
#                  Indicator Code          1960          1961          1962  \
# Country Name
# Aruba         SP.URB.TOTL.IN.ZS  5.077600e+01     50.761000     50.746000
# ...

# %%
# t_df = df.copy()
# t_df = t_df.drop(['Indicator Name', 'Indicator Code', 'Country Code'], axis=1)
# t_df.head()

# %%
df.index.value_counts()['Germany']
# Out:
# 76

# %%
countries = ['Pakistan', 'United States', "United Kingdom", "Germany", "Ireland", "Italy", "Australia", "Canada"]
countries_df = df.loc[countries]
print(countries_df.shape)
countries_df.head()
# Out:
# (608, 66)
#              Country Code                            Indicator Name  \
# Country Name
# Pakistan              PAK  Urban population (% of total population)
# Pakistan              PAK                          Urban population
# Pakistan              PAK        Urban population growth (annual %)
# Pakistan              PAK                         Population, total
# Pakistan              PAK              Population growth (annual %)
#
#                  Indicator Code          1960          1961          1962  \
# Country Name
# Pakistan      SP.URB.TOTL.IN.ZS  2.210400e+01  2.250100e+01  2.275100e+01
# Pakistan            SP.URB.TOTL  1.015772e+07  1.058918e+07  1.095730e+07
# Pakistan            SP.URB.GROW  2.534112e+07  4.159814e+00  3.417355e+00
# Pakistan            SP.POP.TOTL  4.595423e+07  4.706092e+07  4.816184e+07
# Pakistan            SP.POP.GROW  2.534112e+07  2.379701e+00  2.312420e+00
#
# ...

# %%
sel_data = countries_df[df.columns[-13:-3]]

# %%
import matplotlib.pyplot as plt
def line_plot(data, title, xlabel, ylabel):
    plt.title(title)
    plt.plot(data)
    plt.xlabel(xlabel)
    plt.xticks(rotation=90)
    plt.ylabel(ylabel)
    plt.legend(countries, bbox_to_anchor=(1.0, 1), loc="upper right")
    plt.show()

# %%
line_plot(sel_data, "Electric power consumption (kWh per capita)", 
                 "Year", "Electric power consumption (kWh per capita)")

# %%
def process_data(filename):
    df_data = pd.read_csv(filename, header=2)
    df = df_data.drop('Unnamed: 67', axis=1)
    df = df.fillna(df.mean())
    data_years = df.drop(['Country Name',  'Country Code', 'Indicator Name', 'Indicator Code'], axis=1).copy()
    data_countries = df.set_index("Country Name").copy().transpose()
    return data_years, data_countries

# %%
data_years, data_countries = process_data("API_19_DS2_en_csv_v2_5455435\API_19_DS2_en_csv_v2_5455435.csv")
# Out:
# C:\Users\Hammad\AppData\Local\Temp\ipykernel_15116\3364856656.py:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.mean())

# %%
data_years.head()
# Out:
#            1960          1961          1962          1963          1964  \
# 0  5.077600e+01     50.761000     50.746000     50.730000     50.715000
# 1  2.772800e+04  28330.000000  28764.000000  29157.000000  29505.000000
# 2  2.534112e+07      2.147858      1.520329      1.357042      1.186472
# 3  5.460800e+04  55811.000000  56682.000000  57475.000000  58178.000000
# 4  2.534112e+07      2.179059      1.548572      1.389337      1.215721
#
#            1965          1966          1967          1968          1969  ...  \
# 0     50.700000     50.685000     50.670000     50.654000     50.639000  ...
# 1  29802.000000  30052.000000  30160.000000  30124.000000  30044.000000  ...
# 2      1.001576      0.835371      0.358733     -0.119435     -0.265922  ...
# 3  58782.000000  59291.000000  59522.000000  59471.000000  59330.000000  ...
# 4      1.032841      0.862184      0.388847     -0.085719     -0.237372  ...
#
# ...

# %%
data_countries.head()
# Out:
# Country Name                                       Aruba             Aruba  \
# Country Code                                         ABW               ABW
# Indicator Name  Urban population (% of total population)  Urban population
# Indicator Code                         SP.URB.TOTL.IN.ZS       SP.URB.TOTL
# 1960                                              50.776           27728.0
# 1961                                              50.761           28330.0
#
# Country Name                                 Aruba              Aruba  \
# Country Code                                   ABW                ABW
# Indicator Name  Urban population growth (annual %)  Population, total
# Indicator Code                         SP.URB.GROW        SP.POP.TOTL
# 1960                               25341121.231361            54608.0
# 1961                                      2.147858            55811.0
#
# Country Name                           Aruba  \
# ...

# %%
data_countries.index
# Out:
# Index(['Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
data_years[-10:-1][::-1]
# Out:
#                1960          1961          1962          1963          1964  \
# 20214  2.534112e+07  2.839602e+01  2.861574e+01  2.883547e+01  2.905519e+01
# 20213  2.534112e+07  4.872690e+00  5.001939e+00  5.131188e+00  5.260437e+00
# 20212  2.534112e+07  1.641939e+07  1.707373e+07  1.820498e+07  1.876737e+07
# 20211  2.534112e+07  1.641939e+07  1.707373e+07  1.820498e+07  1.876737e+07
# 20210  2.534112e+07  1.641939e+07  1.707373e+07  1.820498e+07  1.876737e+07
# 20209  2.534112e+07  1.641939e+07  1.707373e+07  1.820498e+07  1.876737e+07
# 20208  2.534112e+07  1.641939e+07  1.707373e+07  1.820498e+07  1.876737e+07
# 20207  2.534112e+07  1.641939e+07  1.707373e+07  1.820498e+07  1.876737e+07
# 20206  2.534112e+07  1.641939e+07  1.707373e+07  1.820498e+07  1.876737e+07
#
#                1965          1966          1967          1968          1969  \
# 20214  2.922321e+01  2.949464e+01  2.971436e+01  2.993408e+01  3.015381e+01
# ...

# %%
# Summary statistics for CO2 emissions (metric tons per capita) for individual countries
countries = ['Pakistan', 'United States', "United Kingdom", "Germany", "Ireland", "Italy", "Australia", "Canada"]
co2_data = data_countries[countries]
print(co2_data.describe())
print("Median:", co2_data.median())
print("Variance:", co2_data.var())
# Out:
# Country Name Pakistan Pakistan Pakistan Pakistan Pakistan Pakistan Pakistan  \
# count              66       66       66       66       66       66       66
# unique             66       66       66       66       66       66       66
# top               PAK      PAK      PAK      PAK      PAK      PAK      PAK
# freq                1        1        1        1        1        1        1
#
# Country Name Pakistan Pakistan Pakistan  ... Canada Canada Canada Canada  \
# count          66.000       66       66  ...     66     66     66     66
# unique         63.000       66       66  ...     66     66     66     66
# top             0.034      PAK      PAK  ...    CAN    CAN    CAN    CAN
# freq            3.000        1        1  ...      1      1      1      1
#
# Country Name Canada Canada Canada     Canada Canada Canada
# count            66     66     66  66.000000     66     66
# unique           66     66     66  65.000000     66     66
# ...

# %%
# Summary statistics for CO2 emissions (metric tons per capita) for the world
co2_data_world = data_years[]
print(co2_data_world.describe())
print("Median:", co2_data_world.median())
print("Variance:", co2_data_world.var())

# %%
def line_plot(df, title, xlabel, ylabel):
    countries = ['Chile', 'Zimbabwe',"India", "Tanzania","Netherlands", 
                 "Pakistan", "United States"]
    data = df.iloc[-10:]
    countries_df = data[countries]
    plt.title(title)
    plt.plot(countries_df)
    plt.xlabel(xlabel)
    plt.xticks(rotation=90)
    plt.ylabel(ylabel)
    plt.legend(countries, bbox_to_anchor=(1.0, 1), loc="upper right")
    plt.show()
    
def create_bar_graph(data, title, xlabel, ylabel):
    countries = ['Chile', 'Zimbabwe',"India", "Tanzania", "Afghanistan",
                 "Liberia", "Netherlands", "Pakistan"]
    data = data.iloc[:10]
    data = data[countries]
    plt.figure(figsize=(8,6))
    # last_years_data = last_years_data.T
    ax = data.plot(kind='bar', figsize=(10, 6))
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.legend(bbox_to_anchor=(1.0, 1), loc="upper right")
    plt.show()

# %%
line_plot(df, "Electricity production from coal sources (% of total)", 
                 "Year", "Electricity production from coal")

# %%
create_bar_graph(forest_yearly, "Forest Area", "Year", "Persons")
create_bar_graph(co2_yearly, "CO2 emissions (metric tons per capita)", 
                 "Year", "CO2")

# %%
df.index.unique()
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %%
import numpy as np
# Select 10 random countries from the data
countries = np.random.choice(df.index.unique(), size=5, replace=False)
print(countries)
print(len(countries))
# Select two indicators
indicators = ["Urban population", "Population, total"]
# Out:
# ['Nauru' 'Paraguay' 'Middle East & North Africa' 'Serbia' 'Ukraine']
# 5

# %%
data1 = df.loc[df.index.isin(countries) & (df['Indicator Name'] == 'Urban population')]
data1
# Out:
#                            Country Code    Indicator Name Indicator Code  \
# Country Name
# Middle East & North Africa          MEA  Urban population    SP.URB.TOTL
# Nauru                               NRU  Urban population    SP.URB.TOTL
# Paraguay                            PRY  Urban population    SP.URB.TOTL
# Serbia                              SRB  Urban population    SP.URB.TOTL
# Ukraine                             UKR  Urban population    SP.URB.TOTL
#
#                                   1960        1961        1962        1963  \
# Country Name
# Middle East & North Africa  36622632.0  38385899.0  40259955.0  42232743.0
# Nauru                           4582.0      4753.0      4950.0      5198.0
# Paraguay                      673972.0    692429.0    711620.0    732467.0
# Serbia                       1920549.0   1999961.0   2079912.0   2160366.0
# Ukraine                     20011652.0  20616692.0  21213021.0  21798938.0
#
# ...

# %%
data2 = df.loc[df.index.isin(countries) & (df['Indicator Name'] == 'Population, total')]
data2
# Out:
#                            Country Code     Indicator Name Indicator Code  \
# Country Name
# Middle East & North Africa          MEA  Population, total    SP.POP.TOTL
# Nauru                               NRU  Population, total    SP.POP.TOTL
# Paraguay                            PRY  Population, total    SP.POP.TOTL
# Serbia                              SRB  Population, total    SP.POP.TOTL
# Ukraine                             UKR  Population, total    SP.POP.TOTL
#
#                                    1960         1961         1962  \
# Country Name
# Middle East & North Africa  104958259.0  107670788.0  110538003.0
# Nauru                            4582.0       4753.0       4950.0
# Paraguay                      1894829.0    1941208.0    1989376.0
# Serbia                        6608000.0    6655000.0    6696000.0
# Ukraine                      42767251.0   43365219.0   43924755.0
#
#                                    1963         1964         1965  \
# Country Name
# ...

# %%
data_plot = data1[data1.columns[-13:-3]]
data_plot
# Out:
#                                    2010         2011         2012  \
# Country Name
# Middle East & North Africa  248421309.0  254476115.0  260609701.0
# Nauru                           10241.0      10283.0      10444.0
# Paraguay                      3418538.0    3482053.0    3548485.0
# Serbia                        4009779.0    3994308.0    3985121.0
# Ukraine                      31465493.0   31395053.0   31360012.0
#
#                                    2013         2014         2015  \
# Country Name
# Middle East & North Africa  267522878.0  274769467.0  282176862.0
# Nauru                           10694.0      10940.0      11185.0
# Paraguay                      3615222.0    3683303.0    3753105.0
# Serbia                        3973872.0    3963388.0    3951845.0
# Ukraine                      31330995.0   31223300.0   31183829.0
#
#                                    2016         2017         2018         2019
# Country Name
# ...

# %%
df.loc[countries][df['Indicator Name'] == indicators[0]]
# Out:
# [Country Name
#  Aruba       False
#  Aruba        True
#  Aruba       False
#  Aruba       False
#  Aruba       False
#              ...
#  Zimbabwe    False
#  Zimbabwe    False
#  Zimbabwe    False
#  Zimbabwe    False
#  Zimbabwe    False
#  Name: Indicator Name, Length: 20216, dtype: bool]

# %%
# Loop over the indicators and create a bar chart for each one
for indicator in indicators:
    # Filter the data for the selected countries and indicator
    #data = df.loc[countries][df['Indicator Name'] == indicator].transpose()
    
    # Create a bar chart
    plt.figure()
    plt.bar(data1.index, data1['avg_year'])
    plt.title(indicator)
    plt.xlabel('Year')
    plt.ylabel('Population')
    plt.show()

# %%
data_plot.transpose()
# Out:
# Country Name   Argentina       Ghana  Hong Kong SAR, China        Japan  \
# 2011          37543830.0  13468281.0             7071600.0  116416235.0
# 2012          38027774.0  13986163.0             7150100.0  116331281.0
# 2013          38509756.0  14519202.0             7178900.0  116262976.0
# 2014          38990109.0  15062212.0             7229500.0  116208079.0
# 2015          39467043.0  15615136.0             7291300.0  116182717.0
# 2016          39940546.0  16180685.0             7336600.0  116219897.0
# 2017          40410674.0  16745249.0             7393200.0  116223820.0
# 2018          40877099.0  17306081.0             7452600.0  116179166.0
# 2019          41339571.0  17875345.0             7507900.0  116119928.0
# 2020          41796990.0  18455138.0             7481000.0  115884871.0
#
# Country Name    Lao PDR  St. Martin (French part)       Oman  Seychelles  \
# 2011          1967246.0              6.032894e+08  2443090.0     46973.0
# ...

# %%
data_plot.head()
# Out:
#                              2011         2012         2013         2014  \
# Country Name
# Argentina              37543830.0   38027774.0   38509756.0   38990109.0
# Ghana                  13468281.0   13986163.0   14519202.0   15062212.0
# Hong Kong SAR, China    7071600.0    7150100.0    7178900.0    7229500.0
# Japan                 116416235.0  116331281.0  116262976.0  116208079.0
# Lao PDR                 1967246.0    2034912.0    2103788.0    2173853.0
#
#                              2015         2016         2017         2018  \
# Country Name
# Argentina              39467043.0   39940546.0   40410674.0   40877099.0
# Ghana                  15615136.0   16180685.0   16745249.0   17306081.0
# Hong Kong SAR, China    7291300.0    7336600.0    7393200.0    7452600.0
# Japan                 116182717.0  116219897.0  116223820.0  116179166.0
# Lao PDR                 2247179.0    2324870.0    2405044.0    2487036.0
#
#                              2019         2020
# ...

# %%
# Define the data
data = data_plot.values
labels = data_plot.index
x = np.arange(len(labels))
width = 0.15
gap = 5
num_groups = data.shape[1] // 5  # assuming 5 bars per group


# Create the figure and axes
fig, ax = plt.subplots(figsize = (12,6))

# Create the bars
for i in range(data.shape[1]):
    group_idx = i // 5
    ax.bar(x + (i % 5) * width + group_idx * gap, data[:, i], width, label=data_plot.columns[i])

# Add some labels and formatting
ax.set_xticks(x + ((data.shape[1] - 1) % 5 + 1) / 2 * width + ((num_groups - 1) * gap) / 2)
ax.set_xticklabels(labels)
ax.legend()


ax.ticklabel_format(axis='y', style='plain')

# plt.title(title)
# plt.xlabel(xlabel)
plt.xticks(rotation=90)
# plt.ylabel(ylabel)
# plt.legend(countries, bbox_to_anchor=(1.0, 1), loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 6))
bar_width = 0.15
gap = 0.03

# Create the bars
for i, col in enumerate(data_plot.columns):
    x_pos = np.arange(len(data_plot.index)) + i * (bar_width + gap)
    ax.bar(x_pos, data_plot[col], bar_width, label=col)

# Add some labels and formatting
ax.set_xticks(np.arange(len(data_plot.index)) + len(data_plot.columns) * bar_width / 2 - bar_width / 2)
ax.set_xticklabels(data_plot.index)
ax.legend()

plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
# Create the figure and axes
fig, ax = plt.subplots(figsize = (14,8))

width = 0.15

# Create the bars
for i in range(data.shape[1]):
    ax.bar(x + i * width, data[:, i], width, label=data_plot.columns[i])

# Add some labels and formatting
ax.set_xticks(x + width * (data.shape[1] - 1) / 2)
ax.set_xticklabels(labels)
ax.legend()

# Set ylim
ax.set_ylim([data.min(), data.max()])

plt.xticks(rotation=90)


# Show the plot
plt.show()

# %%
# create a dictionary with the data

# create a bar chart with the data
plt.bar(data1.keys(), data1.values())

# set the title and axis labels
plt.title('Population of Pakistan and India in 2010 and 2011')
plt.xlabel('Country and Year')
plt.ylabel('Population')

# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 4
#       1 # create a dictionary with the data
#       2
#       3 # create a bar chart with the data
# ----> 4 plt.bar(data1.keys(), data1.values())
#       6 # set the title and axis labels
#       7 plt.title('Population of Pakistan and India in 2010 and 2011')
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
ax = data_plot.plot(kind='bar', figsize=(10, 6))
plt.legend(bbox_to_anchor=(1.0, 1), loc="upper right")

# %%
data_plot.describe()
# Out:
#                2010          2011          2012          2013          2014  \
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   5.746507e+07  5.867156e+07  5.990275e+07  6.129073e+07  6.273008e+07
# std    1.074940e+08  1.101817e+08  1.129022e+08  1.159701e+08  1.191922e+08
# min    1.024100e+04  1.028300e+04  1.044400e+04  1.069400e+04  1.094000e+04
# 25%    3.418538e+06  3.482053e+06  3.548485e+06  3.615222e+06  3.683303e+06
# 50%    4.009779e+06  3.994308e+06  3.985121e+06  3.973872e+06  3.963388e+06
# 75%    3.146549e+07  3.139505e+07  3.136001e+07  3.133100e+07  3.122330e+07
# max    2.484213e+08  2.544761e+08  2.606097e+08  2.675229e+08  2.747695e+08
#
#                2015          2016          2017          2018          2019
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   6.421537e+07  6.559958e+07  6.690710e+07  6.824797e+07  6.957195e+07
# ...

# %%
print("Median:", data_plot.median())
print("Variance:", data_plot.var())
# Out:
# Median: 2010    4009779.0
# 2011    3994308.0
# 2012    3985121.0
# 2013    3973872.0
# 2014    3963388.0
# 2015    3951845.0
# 2016    3939250.0
# 2017    3927608.0
# 2018    3968124.0
# 2019    4040715.0
# dtype: float64
# Variance: 2010    1.155495e+16
# 2011    1.214002e+16
# 2012    1.274691e+16
# 2013    1.344905e+16
# 2014    1.420678e+16
# 2015    1.500196e+16
# 2016    1.576532e+16
# 2017    1.650608e+16
# 2018    1.728587e+16
# 2019    1.807530e+16
# dtype: float64
