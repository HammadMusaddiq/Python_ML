# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
dataset = pd.read_csv('SmoteSample.csv')
dataset.shape
# Out:
# (100, 6)

# %%
dataset.head(3)
# Out:
#   Column1  Column2  Column3 Column4  Column5 Class
# 0     yes       11       14      no       40     A
# 1     yes       12       15      no       41     B
# 2     yes       13       16     yes       42     A

# %%
dataset.Class.unique()
# Out:
# array(['A', 'B', 'C', 'D'], dtype=object)

# %%
dataset.dtypes
# Out:
# Column1    object
# Column2     int64
# Column3     int64
# Column4    object
# Column5     int64
# Class      object
# dtype: object

# %%
sel_features = ['Column1', 'Column4']

# %%
print(dataset.shape)

# keeping the columns we need 
raw_data = dataset[sel_features]
print(raw_data.shape)

# Making categorical variables into numeric representation
new_raw_data = pd.get_dummies(raw_data, columns = sel_features)

# print the shape
print(new_raw_data.shape)
new_raw_data
# Out:
# (100, 6)
# (100, 2)
# (100, 4)
#     Column1_no  Column1_yes  Column4_no  Column4_yes
# 0            0            1           1            0
# 1            0            1           1            0
# 2            0            1           0            1
# 3            1            0           1            0
# 4            1            0           0            1
# ..         ...          ...         ...          ...
# 95           0            1           1            0
# 96           0            1           0            1
# 97           1            0           1            0
# 98           1            0           0            1
# 99           0            1           1            0
#
# [100 rows x 4 columns]

# %%
result = pd.concat([dataset, new_raw_data], axis=1)
result
# Out:
#    Column1  Column2  Column3 Column4  Column5 Class  Column1_no  Column1_yes  \
# 0      yes       11       14      no       40     A           0            1
# 1      yes       12       15      no       41     B           0            1
# 2      yes       13       16     yes       42     A           0            1
# 3       no       14       11      no       43     C           1            0
# 4       no       15       12     yes       44     D           1            0
# ..     ...      ...      ...     ...      ...   ...         ...          ...
# 95     yes       12       15      no       41     C           0            1
# 96     yes       13       16     yes       42     D           0            1
# 97      no       16       13      no       50     C           1            0
# 98      no       17       14     yes       51     D           1            0
# 99     yes       12       15      no       41     C           0            1
#
#     Column4_no  Column4_yes
# 0            1            0
# 1            1            0
# 2            0            1
# 3            1            0
# 4            0            1
# ..         ...          ...
# 95           1            0
# 96           0            1
# 97           1            0
# 98           0            1
# 99           1            0
#
# [100 rows x 10 columns]

# %%
data1 = result.drop(['Column1', 'Column4'], axis=1)
data1
# Out:
#     Column2  Column3  Column5 Class  Column1_no  Column1_yes  Column4_no  \
# 0        11       14       40     A           0            1           1
# 1        12       15       41     B           0            1           1
# 2        13       16       42     A           0            1           0
# 3        14       11       43     C           1            0           1
# 4        15       12       44     D           1            0           0
# ..      ...      ...      ...   ...         ...          ...         ...
# 95       12       15       41     C           0            1           1
# 96       13       16       42     D           0            1           0
# 97       16       13       50     C           1            0           1
# 98       17       14       51     D           1            0           0
# 99       12       15       41     C           0            1           1
#
#     Column4_yes
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1
# ..          ...
# 95            0
# 96            1
# 97            0
# 98            1
# 99            0
#
# [100 rows x 8 columns]

# %%
x = data1.drop(['Class'], axis=1)
x
# Out:
#     Column2  Column3  Column5  Column1_no  Column1_yes  Column4_no  \
# 0        11       14       40           0            1           1
# 1        12       15       41           0            1           1
# 2        13       16       42           0            1           0
# 3        14       11       43           1            0           1
# 4        15       12       44           1            0           0
# ..      ...      ...      ...         ...          ...         ...
# 95       12       15       41           0            1           1
# 96       13       16       42           0            1           0
# 97       16       13       50           1            0           1
# 98       17       14       51           1            0           0
# 99       12       15       41           0            1           1
#
#     Column4_yes
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1
# ..          ...
# 95            0
# 96            1
# 97            0
# 98            1
# 99            0
#
# [100 rows x 7 columns]

# %%
x.dtypes
# Out:
# Column2        int64
# Column3        int64
# Column5        int64
# Column1_no     uint8
# Column1_yes    uint8
# Column4_no     uint8
# Column4_yes    uint8
# dtype: object

# %%
x = x.astype('int64')
x
# Out:
#     Column2  Column3  Column5  Column1_no  Column1_yes  Column4_no  \
# 0        11       14       40           0            1           1
# 1        12       15       41           0            1           1
# 2        13       16       42           0            1           0
# 3        14       11       43           1            0           1
# 4        15       12       44           1            0           0
# ..      ...      ...      ...         ...          ...         ...
# 95       12       15       41           0            1           1
# 96       13       16       42           0            1           0
# 97       16       13       50           1            0           1
# 98       17       14       51           1            0           0
# 99       12       15       41           0            1           1
#
#     Column4_yes
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1
# ..          ...
# 95            0
# 96            1
# 97            0
# 98            1
# 99            0
#
# [100 rows x 7 columns]

# %%
y = data1['Class']
y = y.values
y
# Out:
# array(['A', 'B', 'A', 'C', 'D', 'C', 'D', 'A', 'C', 'A', 'C', 'A', 'B',
#        'C', 'A', 'C', 'A', 'C', 'A', 'C', 'A', 'A', 'C', 'A', 'C', 'A',
#        'C', 'C', 'C', 'C', 'A', 'C', 'A', 'C', 'A', 'C', 'A', 'A', 'C',
#        'A', 'A', 'C', 'A', 'C', 'A', 'C', 'C', 'C', 'C', 'A', 'C', 'C',
#        'A', 'C', 'A', 'A', 'C', 'A', 'C', 'A', 'A', 'A', 'C', 'A', 'C',
#        'A', 'A', 'C', 'A', 'C', 'A', 'C', 'A', 'A', 'C', 'A', 'C', 'A',
#        'C', 'A', 'A', 'C', 'A', 'C', 'A', 'A', 'C', 'D', 'C', 'A', 'B',
#        'A', 'C', 'D', 'A', 'C', 'D', 'C', 'D', 'C'], dtype=object)

# %%
print(x.shape)
print(y.shape)
# Out:
# (100, 7)
# (100,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
print(np.unique(y_train))
print(np.unique(y_test))
# Out:
# ['A' 'B' 'C' 'D']
# ['A' 'C' 'D']

# %%
data1['Class'].value_counts()
# Out:
# A    46
# C    45
# D     6
# B     3
# Name: Class, dtype: int64

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
pred = model.predict(X_test)
acc = accuracy_score(y_test, pred)
print('RF Accuracy: %.4f' % (acc))
# Out:
# RF Accuracy: 0.8333

# %%
print("RF " + accuracy_score(y_test, pred).astype(str))
# Out:
# RF 0.8333333333333334

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[ 8  1  0]
#  [ 2 17  0]
#  [ 2  0  0]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.67      0.89      0.76         9
#            C       0.94      0.89      0.92        19
#            D       0.00      0.00      0.00         2
#
#     accuracy                           0.83        30
#    macro avg       0.54      0.59      0.56        30
# weighted avg       0.80      0.83      0.81        30
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
data2 = data1.copy()

# %%
print(data1['Class'].unique())
print(len(data1['Class'].unique()))

x1 = data1.drop(['Class'], axis=1)
x1 = x1.astype('int64')
x1 = x1.values
print(x1)

y1 = data1['Class']
y1 = y1.values
print(y1)
# Out:
# ['A' 'B' 'C' 'D']
# 4
# [[11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [12 15 41  0  1  1  0]]
# ['A' 'B' 'A' 'C' 'D' 'C' 'D' 'A' 'C' 'A' 'C' 'A' 'B' 'C' 'A' 'C' 'A' 'C'
#  'A' 'C' 'A' 'A' 'C' 'A' 'C' 'A' 'C' 'C' 'C' 'C' 'A' 'C' 'A' 'C' 'A' 'C'
#  'A' 'A' 'C' 'A' 'A' 'C' 'A' 'C' 'A' 'C' 'C' 'C' 'C' 'A' 'C' 'C' 'A' 'C'
#  'A' 'A' 'C' 'A' 'C' 'A' 'A' 'A' 'C' 'A' 'C' 'A' 'A' 'C' 'A' 'C' 'A' 'C'
#  'A' 'A' 'C' 'A' 'C' 'A' 'C' 'A' 'A' 'C' 'A' 'C' 'A' 'A' 'C' 'D' 'C' 'A'
#  'B' 'A' 'C' 'D' 'A' 'C' 'D' 'C' 'D' 'C']

# %%
print(data2['Class'].value_counts())
print(len(data2['Class'].value_counts()))
# Out:
# A    46
# C    45
# D     6
# B     3
# Name: Class, dtype: int64
# 4

# %%
data2.drop(data2[data2['Class'] == 'B'].index, inplace = True) 
#data2.drop(data2[data2['Class'] == 'D'].index, inplace = True) 
print(data2['Class'].unique())
print(len(data2['Class'].unique()))

x2 = data2.drop(['Class'], axis=1)
x2 = x2.astype('int64')
x2 = x2.values
print(x2)

y2 = data2['Class']
y2 = y2.values
print(y2)
# Out:
# ['A' 'C' 'D']
# 3
# [[11 14 40  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [14 11 43  1  0  1  0]
#  [15 12 44  1  0  0  1]
#  [15 12 44  1  0  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [11 14 40  0  1  1  0]
#  [12 15 41  0  1  1  0]
#  [13 16 42  0  1  0  1]
#  [16 13 50  1  0  1  0]
#  [17 14 51  1  0  0  1]
#  [12 15 41  0  1  1  0]]
# ['A' 'A' 'C' 'D' 'C' 'D' 'A' 'C' 'A' 'C' 'A' 'C' 'A' 'C' 'A' 'C' 'A' 'C'
#  'A' 'A' 'C' 'A' 'C' 'A' 'C' 'C' 'C' 'C' 'A' 'C' 'A' 'C' 'A' 'C' 'A' 'A'
#  'C' 'A' 'A' 'C' 'A' 'C' 'A' 'C' 'C' 'C' 'C' 'A' 'C' 'C' 'A' 'C' 'A' 'A'
#  'C' 'A' 'C' 'A' 'A' 'A' 'C' 'A' 'C' 'A' 'A' 'C' 'A' 'C' 'A' 'C' 'A' 'A'
#  'C' 'A' 'C' 'A' 'C' 'A' 'A' 'C' 'A' 'C' 'A' 'A' 'C' 'D' 'C' 'A' 'A' 'C'
#  'D' 'A' 'C' 'D' 'C' 'D' 'C']

# %%
print(data1.shape)
print(data2.shape)
# Out:
# (100, 8)
# (97, 8)

# %%
print(x1.shape)
print(y1.shape)
# Out:
# (100, 7)
# (100,)

# %%
print(x2.shape)
print(y2.shape)
# Out:
# (97, 7)
# (97,)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.3, random_state=0)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.3, random_state=0)

# %%
from imblearn.over_sampling import SMOTE 
smote = SMOTE()
from collections import Counter

# %%
#smote=SMOTE(sampling_strategy='not minority',random_state=10)

# %%
X_S1, y_S1 = smote.fit_resample(x1,y1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-ea0f8391d0f2> in <module>
# ----> 1 X_S1, y_S1 = smote.fit_resample(x1,y1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = label_binarize(output[1], np.unique(y)) if binarize_y else output[1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     307
#     308             self.nn_k_.fit(X_class)
# --> 309             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     310             X_new, y_new = self._make_samples(
#     311                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     678         n_samples_fit = self.n_samples_fit_
#     679         if n_neighbors > n_samples_fit:
# --> 680             raise ValueError(
#     681                 "Expected n_neighbors <= n_samples, "
#     682                 " but n_samples = %d, n_neighbors = %d" %
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 3, n_neighbors = 6

# %%
print("Before Smote :", Counter(y1))
print("After Smote :", Counter(y_S1))

# %%
X_S2, y_S2 = smote.fit_resample(x2,y2)

# %%
print("Before Smote :", Counter(y2))
print("After Smote :", Counter(y_S2))
# Out:
# Before Smote : Counter({'A': 46, 'C': 45, 'D': 6})
# After Smote : Counter({'A': 46, 'C': 46, 'D': 46})

# %%
X_S11, y_S11 = smote.fit_resample(X_train1,y_train1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-d4aa0860d85b> in <module>
# ----> 1 X_S11, y_S11 = smote.fit_resample(X_train1,y_train1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = label_binarize(output[1], np.unique(y)) if binarize_y else output[1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     307
#     308             self.nn_k_.fit(X_class)
# --> 309             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     310             X_new, y_new = self._make_samples(
#     311                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     678         n_samples_fit = self.n_samples_fit_
#     679         if n_neighbors > n_samples_fit:
# --> 680             raise ValueError(
#     681                 "Expected n_neighbors <= n_samples, "
#     682                 " but n_samples = %d, n_neighbors = %d" %
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 3, n_neighbors = 6

# %%
print("Before Smote :", Counter(y_train1))
print("After Smote :", Counter(y_S11))
# Out:
# Before Smote : Counter({'A': 37, 'C': 26, 'D': 4, 'B': 3})
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-46fe684271a4> in <module>
#       1 print("Before Smote :", Counter(y_train1))
# ----> 2 print("After Smote :", Counter(y_S11))
#
# NameError: name 'y_S11' is not defined

# %%
X_S22, y_S22 = smote.fit_resample(X_train2,y_train2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-449f2942d252> in <module>
# ----> 1 X_S22, y_S22 = smote.fit_resample(X_train2,y_train2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = label_binarize(output[1], np.unique(y)) if binarize_y else output[1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     307
#     308             self.nn_k_.fit(X_class)
# --> 309             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     310             X_new, y_new = self._make_samples(
#     311                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     678         n_samples_fit = self.n_samples_fit_
#     679         if n_neighbors > n_samples_fit:
# --> 680             raise ValueError(
#     681                 "Expected n_neighbors <= n_samples, "
#     682                 " but n_samples = %d, n_neighbors = %d" %
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 6

# %%
print("Before Smote :", Counter(y_train2))
print("After Smote :", Counter(y_S22))
# Out:
# Before Smote : Counter({'A': 34, 'C': 28, 'D': 5})
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-cf5c86352de5> in <module>
#       1 print("Before Smote :", Counter(y_train2))
# ----> 2 print("After Smote :", Counter(y_S22))
#
# NameError: name 'y_S22' is not defined

# %%
print(X_S22.shape)
print(y_S22.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-f806a9908987> in <module>
# ----> 1 print(X_S22.shape)
#       2 print(y_S22.shape)
#
# NameError: name 'X_S22' is not defined

# %%
print(X_S2.shape)
print(y_S2.shape)
# Out:
# (138, 7)
# (138,)

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X_S2, y_S2, test_size=0.3, random_state=0)

# %%
#Use GAN model to increase the instances of minority class. Increase there rows to atleast 6 instances.

# %%
data3 = data1.copy()

# %%
data3.drop(data3[data3['Class'] == 'A'].index, inplace = True) 
data3.drop(data3[data3['Class'] == 'C'].index, inplace = True) 
data3
# Out:
#     Column2  Column3  Column5 Class  Column1_no  Column1_yes  Column4_no  \
# 1        12       15       41     B           0            1           1
# 4        15       12       44     D           1            0           0
# 6        17       14       51     D           1            0           0
# 12       16       13       50     B           1            0           1
# 87       13       16       42     D           0            1           0
# 90       16       13       50     B           1            0           1
# 93       17       14       51     D           1            0           0
# 96       13       16       42     D           0            1           0
# 98       17       14       51     D           1            0           0
#
#     Column4_yes
# 1             0
# 4             1
# 6             1
# 12            0
# 87            1
# 90            0
# 93            1
# 96            1
# 98            1

# %%
new_row = {'Column2': 12, 'Column3':17, 'Column5':92, 'Class':'D', 'Column1_no' : 0,  'Column1_yes': 1, 'Column4_no':1, \
           "Column4_yes":0}
new_row
# Out:
# {'Column2': 12,
#  'Column3': 17,
#  'Column5': 92,
#  'Class': 'D',
#  'Column1_no': 0,
#  'Column1_yes': 1,
#  'Column4_no': 1,
#  'Column4_yes': 0}

# %%
data3 = data3.append(new_row, ignore_index=True)
data3
# Out:
#    Column2  Column3  Column5 Class  Column1_no  Column1_yes  Column4_no  \
# 0       12       15       41     B           0            1           1
# 1       15       12       44     D           1            0           0
# 2       17       14       51     D           1            0           0
# 3       16       13       50     B           1            0           1
# 4       13       16       42     D           0            1           0
# 5       16       13       50     B           1            0           1
# 6       17       14       51     D           1            0           0
# 7       13       16       42     D           0            1           0
# 8       17       14       51     D           1            0           0
# 9       12       17       92     D           0            1           1
#
#    Column4_yes
# 0            0
# 1            1
# 2            1
# 3            0
# 4            1
# 5            0
# 6            1
# 7            1
# 8            1
# 9            0

# %%
discrete_columns = ['Class']

# %%
from ctgan import CTGANSynthesizer
ctgan = CTGANSynthesizer(epochs=1)
ctgan.fit(data3, discrete_columns)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,

# %%
samples = ctgan.sample(400)
samples
# Out:
#      Column2  Column3  Column5 Class  Column1_no  Column1_yes  Column4_no  \
# 0         16       16       37     B           1            0           0
# 1         11       11      107     D           0            0           0
# 2         18       13       54     B           0            1           0
# 3         18       11       53     B           0            0           0
# 4         10       14       49     D           0            0           1
# ..       ...      ...      ...   ...         ...          ...         ...
# 395       14       12      102     B           0            0           0
# 396       17       11       55     D           0            0           1
# 397       19       13       48     D           0            0           0
# 398       12       12       98     D           0            0           0
# 399       17       15       99     B           0            0           0
#
#      Column4_yes
# 0              0
# 1              1
# 2              1
# 3              0
# 4              0
# ..           ...
# 395            0
# 396            1
# 397            0
# 398            0
# 399            0
#
# [400 rows x 8 columns]

# %%
samples['Class'].value_counts()
# Out:
# B    205
# D    195
# Name: Class, dtype: int64

# %%
data4 = data1.copy()

# %%
data4.drop(data4[data4['Class'] == 'B'].index, inplace = True) 
data4.drop(data4[data4['Class'] == 'D'].index, inplace = True) 
data4
# Out:
#     Column2  Column3  Column5 Class  Column1_no  Column1_yes  Column4_no  \
# 0        11       14       40     A           0            1           1
# 2        13       16       42     A           0            1           0
# 3        14       11       43     C           1            0           1
# 5        16       13       50     C           1            0           1
# 7        11       14       40     A           0            1           1
# ..      ...      ...      ...   ...         ...          ...         ...
# 92       16       13       50     C           1            0           1
# 94       11       14       40     A           0            1           1
# 95       12       15       41     C           0            1           1
# 97       16       13       50     C           1            0           1
# 99       12       15       41     C           0            1           1
#
#     Column4_yes
# 0             0
# 2             1
# 3             0
# 5             0
# 7             0
# ..          ...
# 92            0
# 94            0
# 95            0
# 97            0
# 99            0
#
# [91 rows x 8 columns]

# %%
data4['Class'].value_counts()
# Out:
# A    46
# C    45
# Name: Class, dtype: int64

# %%
frames = [samples, data4]

# %%
result = pd.concat(frames)
result = result.reset_index(drop=True)
result
# Out:
#      Column2  Column3  Column5 Class  Column1_no  Column1_yes  Column4_no  \
# 0         16       16       37     B           1            0           0
# 1         11       11      107     D           0            0           0
# 2         18       13       54     B           0            1           0
# 3         18       11       53     B           0            0           0
# 4         10       14       49     D           0            0           1
# ..       ...      ...      ...   ...         ...          ...         ...
# 486       16       13       50     C           1            0           1
# 487       11       14       40     A           0            1           1
# 488       12       15       41     C           0            1           1
# 489       16       13       50     C           1            0           1
# 490       12       15       41     C           0            1           1
#
#      Column4_yes
# 0              0
# 1              1
# 2              1
# 3              0
# 4              0
# ..           ...
# 486            0
# 487            0
# 488            0
# 489            0
# 490            0
#
# [491 rows x 8 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Column2      491 non-null    int64
#  1   Column3      491 non-null    int64
#  2   Column5      491 non-null    int64
#  3   Class        491 non-null    object
#  4   Column1_no   491 non-null    int64
#  5   Column1_yes  491 non-null    int64
#  6   Column4_no   491 non-null    int64
#  7   Column4_yes  491 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 30.8+ KB

# %%
result['Class'].value_counts()
# Out:
# B    205
# D    195
# A     46
# C     45
# Name: Class, dtype: int64
